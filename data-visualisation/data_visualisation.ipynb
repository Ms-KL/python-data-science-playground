# %% [markdown]
# # <font color='blue'>**Python Data Visualisation**</font>

# %% [markdown]
# ## Resources & References:
# * [Free Code Camp: Data Visualization using Python, Matplotlib, and Seaborn](https://www.freecodecamp.org/news/exploratory-data-analysis-with-numpy-pandas-matplotlib-seaborn/#data-visualization-using-python-matplotlib-and-seaborn)
# * [Direct Tutorial on Jovian](https://jovian.com/aakashns/python-matplotlib-data-visualization)
# * [MatPlotLib vs Seaborn](https://datauntold.com/matplotlib-vs-seaborn/)
#
# ## Tutorial Summary:
# * How to:
#     * create and customize line charts using Matplotlib
#     * visualize relationships between two or more variables using scatter plots
#     * study distributions of variables using histograms and bar charts
#     * visualize two-dimensional data using heatmaps
#     * display images using Matplotlib's plt.imshow
#     * multiple Matplotlib and Seaborn charts in a grid
#
#     <br>
# * References to learn and discover more:
#     * Data Visualization cheat sheet: https://jovian.ml/aakashns/dataviz-cheatsheet
#     * Seaborn gallery: https://seaborn.pydata.org/examples/index.html
#     * Matplotlib gallery: https://matplotlib.org/3.1.1/gallery/index.html
#     * Matplotlib tutorial: https://github.com/rougier/matplotlib-tutorial
#
# ## Notebook Contents:
# 1. **[Install and Import libraries: `MatPlotLib` and `Seaborn`](#1.-Install-&-import-libraries:-matplotlib-and-seaborn)**
#
#     <br>
# 2. **[Create a Line Chart](#2.-Create-a-Line-Chart)**
#     * [Create a line chart using `MatPlotLib`](#Create-a-Line-Chart-using-MatPlotLib:)
#     * [Improve the line chart using `Seaborn`](#Improve-the-Line-Chart-using-Seaborn:)
#
#     <br>
# 3. **[Create a Scatter Plot](#3.-Create-a-Scatter-Plot)**
#     * [Scatter Plots in `MatPlotLib`](#Scatter-Plots-in-MatPlotLib:)
#     * [Add Hues in `MatPlotLib`](#Add-Hues-in-MatPlotLib:)
#     * [Customise `Seaborn` Figures](#Customize-Seaborn-Figures:)
#     * [Plot Data using `Pandas` Data Frames with `Seaborn`](#Plot-Data-using-Pandas-Data-Frames-with-Seaborn:)
#
#     <br>
# 4. **[Create a Histogram](#3.-Create-a-Histogram)**
#     * [Histograms in `MatPlotLib`](#Histograms-in-MatPlotLib:)

# %% [markdown]
# <font color='green'> ***Run code below if starting from top to reset flow and presets:***</font>

# %%
# Run this code if starting from top to reset flow:
sns.reset_defaults()
# Or: mpl.rc_file_defaults()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\GIT\ms-kl\python-data-science-playground\data-visualisation\data_visualisation.ipynb Cell 4 in 2
#       <a href='vscode-notebook-cell:/c%3A/GIT/ms-kl/python-data-science-playground/data-visualisation/data_visualisation.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> # Run this code if starting from top to reset flow:
# ----> <a href='vscode-notebook-cell:/c%3A/GIT/ms-kl/python-data-science-playground/data-visualisation/data_visualisation.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> sns.reset_defaults()
#
# NameError: name 'sns' is not defined

# %% [markdown]
# ---
#
# ## <font color='blue'>1. Install & import libraries: matplotlib and seaborn</font>

# %% [markdown]
# ## MatPlotLib vs Seaborn:
# [⇡ Back to top](#Python-Data-Visualisation)
#
# * **Matplotlib is a general-purpose plotting library for Python**.
#     * *Use it for*:
#         * basic plots
#         * default styling
#         * graphical visualisation for numpy and pandas
#         * accessing extensive library of functions, but with complex syntax
#     * *Cannot use for*:
#         * plotting categorical variables with boxplots or violin plot
#         * visualising regression models
#         * custom styling
#
# * **Seaborn is a Python data visualization library based on matplotlib**.
#     * *Use it for*:
#         * more advanced statistical plots
#         * visualising regression models
#         * custom styling
#         * functions to plot categorical variables with boxplots and violin plots
#         * compatibility with dataframes in pandas
#         * simpler syntax

# %%
# %pip install matplotlib seaborn --upgrade --quiet

# %%
import matplotlib.pyplot as plt #alias
import seaborn as sns #alias
# matplotlib as mpl declared below

# %matplotlib inline 
# ensures plots are shown and embedded within this notebook - otherwise it may showup as popup

# %% [markdown]
# ---
# ## <font color='blue'>2. Create a Line Chart</font>
# Displays a serials of data points or markers, connected by straight lines

# %% [markdown]
# ### Create a Line Chart using MatPlotLib:
# [⇡ Back to top](#Python-Data-Visualisation)
#
# * Create a **list** showing yield of apples (tons per hectare) over 6 years in Kristyland

# %%
yield_apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931]

# %% [markdown]
# * visualise how the yield of apples change over time using a line chart using **matplotlib** (plt)

# %%
plt.plot(yield_apples)

# %% [markdown]
# * just output the graph (**remove the output line**):

# %%
plt.plot(yield_apples);

# %% [markdown]
# * **display the year** for the x-axis (horizontal), instead of the 0-5 indicies

# %%
years = [2010, 2011, 2012, 2013, 2014, 2015]
plt.plot(years, yield_apples);

# %% [markdown]
# * **add axis labels** (y and x)

# %%
plt.xlabel('Year') #horizontal
# Out:
# Text(0.5, 0, 'Year')

# %%
plt.ylabel('Yeild (tons per hectare)'); #vertical

# %% [markdown]
# * **combine the labels and plotted data** (in the same output)

# %%
plt.plot(years, yield_apples)
plt.xlabel('Year')
plt.ylabel('Yeild (tons per hectare)');

# %% [markdown]
# * **plot multiple lines** of data

# %%
years = range(2000, 2012)
# range shortcut - instead of years list

apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931, 0.934, 0.936, 0.937, 0.9375, 0.9372, 0.939]
# first data set

oranges = [0.962, 0.941, 0.930, 0.923, 0.918, 0.908, 0.907, 0.904, 0.901, 0.898, 0.9, 0.896, ]
# second data set

plt.plot(years, apples) # first data set line
plt.plot(years, oranges) # second data set line

plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)');

# %% [markdown]
# * **add title and legend** to visualisaton

# %%
# plot the data
plt.plot(years, apples)
plt.plot(years, oranges)

# label the axis
plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')

# define the visualisation
plt.title("Crop Yields in Kristyland")
plt.legend(['Apples', 'Oranges']);

# %% [markdown]
# * **add markers** to plotted data
# * [marker list](https://jovian.com/outlink?url=https%3A%2F%2Fmatplotlib.org%2F3.1.1%2Fapi%2Fmarkers_api.html)

# %%
# plot and mark data points
plt.plot(years, apples, marker='o')
plt.plot(years, oranges, marker='*')

# label the axis
plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')

# define the visualisation
plt.title("Crop Yields in KristyLand")
plt.legend(['Apples', 'Oranges']);

# %% [markdown]
# * **style lines and markers**
# * `plt.plot`arguments:
#     * `linestyle or ls` – Choose between a solid or dashed line
#     * `linewidth or lw` – Set the width of a line
#     * `markersize or ms` – Set the size of markers
#     * `markeredgecolor or mec` – Set the edge color for markers
#     * `markeredgewidth or mew` – Set the edge width for markers
#     * `markerfacecolor or mfc` – Set the fill color for markers
#     * `alpha` – Opacity of the plot
#     * `color or c` – Set the color of the line ([supported colors](https://matplotlib.org/3.1.0/gallery/color/named_colors.html))
#
# ![image](matplotlib_colors.png)

# %%
# plot mark and style data
plt.plot(years, apples, marker='*', c='lawngreen', ls='-', lw=2, ms=15, mew=1, mec='navy')

# ls = line style solid
# lw = line width of 2px
# ms = marker size of 15px
# mew = marker edge (outline) width of 1px
# mec = marker edge (outline) color navy

plt.plot(years, oranges, marker='o', c='r', ls='--', lw=3, ms=10, alpha=.5)

# ls = line style dashed
# lw = line width of 3px
# ms = marker size of 10px
# alpha = marker plot opacity 50%

# label the axis
plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')

# define the visualisation
plt.title("Crop Yields in KristyLand")
plt.legend(['Apples', 'Oranges']);

# %% [markdown]
# * **specify marker shape, line style and line color** in shorthand

# %%
fmt = '[marker][line][color]' # shorthand to reference in plt.plot argument

plt.plot(years, apples, '*-b') # s = star marker, - = solid line style , b = blue line color
plt.plot(years, oranges, 'o--r') # o = circle marker, - = dashed line style , r = red line color

plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')

plt.title("Crop Yields in KristyLand")
plt.legend(['Apples', 'Oranges']);

# %% [markdown]
# * **change figure size** in visualisation

# %%
plt.figure(figsize=(12, 6)) # x, y axis

plt.plot(years, oranges, 'or') # o = circle marker, r = color marker red, no line to connect
plt.title("Yield of Oranges (tons per hectare)");

# %% [markdown]
# ### Improve the Line Chart using Seaborn:
# [⇡ Back to top](#Python-Data-Visualisation)

# %% [markdown]
# * review the [pre-defined styles](https://seaborn.pydata.org/generated/seaborn.set_style.html) set by Seaborn
# * **incorporate a grid style** into your line chart

# %%
sns.set_style("whitegrid") # light background
plt.plot(years, apples, 's-b') # marker = square, line = solid, color = blue
plt.plot(years, oranges, 'o--r') # marker = circle, line = dashed, color = red

plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')

plt.title("Crop Yields in Kristyland")
plt.legend(['Apples', 'Oranges']);

# %%
sns.set_style("darkgrid") # dark background
plt.plot(years, apples, 's-b') # marker = square, line = solid, color = blue
plt.plot(years, oranges, 'o--r') # marker = circle, line = dashed, color = red

plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')

plt.title("Crop Yields in Kristyland")
plt.legend(['Apples', 'Oranges']);

# %%
plt.plot(years, oranges, 'or') # marker = circle, color = red
plt.title("Yield of Oranges in Kristy land (tons per hectare)");

# note: continues last sns.set_style action run

# %% [markdown]
# * **edit default style** by modifying the 'matplotlib.rcParams' dictionary. [Read More...](https://matplotlib.org/3.2.1/tutorials/introductory/customizing.html#matplotlib-rcparams)

# %%
import matplotlib as mpl

mpl.rcParams['font.size'] = 20
mpl.rcParams['figure.figsize'] = (10, 10)
mpl.rcParams['figure.facecolor'] = '#00000000'
mpl.rcParams['lines.linestyle'] = '-'
mpl.rcParams['lines.linewidth'] = 5

# %%
plt.plot(years, oranges)
plt.title("Yield of Oranges in Kristy Land (tons per hectare)");

# %%
mpl.rcParams['font.size'] = 14
mpl.rcParams['figure.figsize'] = (9, 5)
mpl.rcParams['figure.facecolor'] = '#00000000'
mpl.rcParams['lines.linestyle'] = '--'
mpl.rcParams['lines.linewidth'] = 2

# %%
plt.plot(years, oranges)
plt.title("Yield of Oranges (tons per hectare)");

# %% [markdown]
# ---
# ## <font color='blue'>3. Create a Scatter Plot</font>

# %% [markdown]
# ### Scatter Plots in MatPlotLib:
# [⇡ Back to top](#Python-Data-Visualisation)
#
# * the values of 2 variables are plotted as points
#     * these are on a 2-dimensional grid
# * use a 3rd variable to style points

# %% [markdown]
# * Use the [iris flower dataset](https://en.wikipedia.org/wiki/Iris_flower_data_set) (included in Seaborn library) to **load data as Pandas dataframe**

# %%
# load data into Pandas dataframe:
flowers_df = sns.load_dataset("iris")

# seaborn.load_dataset = function that returns a pandas dataframe object

# %%
flowers_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# * **print the unique values from an array** based on a specified field

# %%
flowers_df.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %% [markdown]
# * **visualise the relationship between 2 values:** sepal length and width

# %%
plt.plot(
    flowers_df.sepal_length,
    flowers_df.sepal_width
);

# %% [markdown]
# Note: there isn't a simple relationship -> choose a different visualisation for clarity

# %% [markdown]
# * **visualise the data using a scatterplot** with seaborn (sns)

# %%
sns.scatterplot(
    x=flowers_df.sepal_length,
    y=flowers_df.sepal_width,
);

# %% [markdown]
# ### Add Hues in MatPlotLib:
# [⇡ Back to top](#Python-Data-Visualisation)
#
# * Points above form clusters with some outliers
# * Color the dots to **identify the clusters**

# %%
sns.scatterplot(
    x=flowers_df.sepal_length,
    y=flowers_df.sepal_width,
    hue=flowers_df.species, #add the hue based on specified category
    s=100 #s = size of the markers... eg 100px
);

# %% [markdown]
# ### Customize Seaborn Figures:
# [⇡ Back to top](#Python-Data-Visualisation)

# %%
# use pyplot to customise figure:

plt.figure(figsize=(12, 6)) 
#change figure size (note: default was changed prior with: mpl.rcParams['figure.figsize'] = (9, 5))

plt.title('Sepal Dimensions')

# use seaborn to create scatterplot:
sns.scatterplot(x=flowers_df.sepal_length, 
                y=flowers_df.sepal_width, 
                hue=flowers_df.species,
                s=100);

# %% [markdown]
# ### Plot Data using Pandas Data Frames with Seaborn:
# [⇡ Back to top](#Python-Data-Visualisation)
# * Seaborn as built in support for Pandas dataframes
#     * no need to pass each column as a series
#         * provide column names and use data argument to specify data frame

# %%
# set scatterplot title with pyplot:
plt.title('Sepal Dimensions')

# set scatterplot dimensions, hue of individual dot values based on column, 
    # size of markers and data to specify dataframe 
sns.scatterplot(x='sepal_length', 
                y='sepal_width', 
                hue='species', # hue of dot based on unique values in species column
                s=100, # size of marker dot
                data=flowers_df); #data to access for markers

# %% [markdown]
# ---
# ## <font color='blue'>4. Create a Histogram</font>

# %% [markdown]
# ### Histograms in MatPlotLib:
# [⇡ Back to top](#Python-Data-Visualisation)
#
# * Represents distribution of a variable by:
#     * creating bins/intervals along range of values
#     * shows verticals bars to indicate number of observations in each bin/interval

# %%
# Load data into a Pandas dataframe
flowers_df = sns.load_dataset("iris")

# sepal_width = y axis / vertical = frequency
flowers_df.sepal_width

# set the title of the histogram
plt.title("Distribution of Sepal Width in KristyLand")

# plot the histogram using the width data (From scatterplot above)
plt.hist(flowers_df.sepal_width);

# %% [markdown]
# ### Control the size & number of bins in Histograms:
# [⇡ Back to top](#Python-Data-Visualisation)

# %%
# specify the number of bins to change the look of the distribution
plt.hist(flowers_df.sepal_width, bins=5);

# %%
import numpy as np

# specify the boundaries of each bin
# this will use the numpy package to set the bins from 2 to 5 with a step of 0.25
plt.hist(flowers_df.sepal_width, bins=np.arange(2,5,0.25));

# %%
# set bins of unequal sizes (not recommended)
plt.hist(flowers_df.sepal_width, bins=[1,3,4,4.5]);

# %% [markdown]
# ### Managing Multiple Histograms in MatPlotLib:
# [⇡ Back to top](#Python-Data-Visualisation)
#
# * Similar to line charts, we can plot multiple histograms in a single chart:
#     * reduce opacity of bars to see both distributions clearly

# %%
setosa_df = flowers_df[flowers_df.species == 'setosa']
# dataframe for setosa species

versicolor_df = flowers_df[flowers_df.species == 'versicolor']
# dataframe for versicolor species

virginica_df = flowers_df[flowers_df.species == 'virginica']
# dataframe for virginica species

plt.hist(setosa_df.sepal_width, alpha=0.4, bins=np.arange(2,5,0.25));
plt.hist(versicolor_df.sepal_width, alpha=0.4, bins=np.arange(2,5,0.25));
# draw a histogram using setosa dataframe. Plot the bars using sepal_width (y) values
# set the bin range from 2 - 5 with a step of 0.25
# alpha sets the opacity of the bars to 0.4

# %%
# stack histograms onto each other

plt.title('Distribution of Sepal Width in KristyLand')
plt.hist(
    [
    setosa_df.sepal_width, 
    versicolor_df.sepal_width, 
    virginica_df.sepal_width],
    bins=np.arange(2, 5, 0.25),
    stacked=True);

plt.legend(['Setosa', 'Versicolor', 'Virginica']);

# %% [markdown]
# ---
# ## <font color='blue'>5. Create a Bar Chart</font>

# %% [markdown]
# ### Bar Charts in MatPlotLib:
# [⇡ Back to top](#Python-Data-Visualisation)
#
# * Similar to line charts: showing sequence of values
#     * one bar for each value (rather than points connected by lines)

# %%
# set the data

years = range(2000, 2006)
apples = [0.35, 0.6, 0.9, 0.8, 0.65, 0.8]
oranges = [0.4, 0.8, 0.9, 0.7, 0.6, 0.8]

plt.bar(years, oranges);

# %%
# stack bars ontop of eachother (like histograms)
# use bottom argument to specify the bottom of the bar

plt.bar(years, apples)
plt.bar(years, oranges, bottom=apples);
plt.legend(['apples', 'oranges']);

# %% [markdown]
# ---
# ## <font color='blue'>6. Create a Bar Plot</font>

# %% [markdown]
# ### Bar Plots with Averages in Seaborn:
# [⇡ Back to top](#Python-Data-Visualisation)
#
# * draw bar chart to visualise how an average varies across different days of the week
# * lines cutting through bars represent the amount of variation in the values
#     * longer lines = more variation
#     * more variation means the average may not be representative of the data

# %%
# access the tips dataset from seaborn
tips_df = sns.load_dataset("tips")

# view the data
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# compute day averages & visualise using a bar chart
sns.barplot(
    x='day', # day column
    y='total_bill', # average of total_bill
    data=tips_df
    );

# %% [markdown]
# * Note:
#     * the average is not a good representation of the data
#     * the average is not a good summary of the data
#     * a better summary would be the median (middle value)

# %%
# specify the hue to compare bar plots side-by-side when adding a third feature
# feature 1: day
# feature 2: total_bill
# feature 3: sex

sns.barplot(x='day', y='total_bill', hue='sex', data=tips_df);

# %%
# change the plot to be horizontal by switching x and y axis

sns.barplot(x='total_bill', y='day', hue='sex', data=tips_df);

# %% [markdown]
# ---
# ## <font color='blue'>7. Create a Heatmap</font>

# %% [markdown]
# ### Heatmaps in Seaborn:
# [⇡ Back to top](#Python-Data-Visualisation)
#
# * visualise 2-dimensional data (matrix, table et) using a heatmap
# * colours represent values in the matrix
#     * brighter colours = higher values
#     * darker colours = lower values

# %%
# access the flights dataset using Seaborn

# flights_df = sns.load_dataset("flights").pivot("month", "year", "passengers")
# ! TypeError: pivot() takes 1 positional argument but 4 were given

flights_df = sns.load_dataset("flights").pivot(index="month", columns="year", values="passengers")

# pivot the data to make it easier to plot
    # pivot = reorganise the data to make it easier to plot

# view the data
flights_df

# flights_df = matrix = one row per month, one column per year
# values in 1000s (visited airport in that month)
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
# visualise the data using a heatmap

plt.title("Kristy's Heatmap: Number of Passengers (1000s)")

sns.heatmap(flights_df);

# %%
# display actual values int eh block and change the color palette

plt.title("Kristy's edited number of passengers (1000s)")
sns.heatmap(
    flights_df,
    fmt='d', # display actual values in the block
    annot=True, # display the values in the block - annot = annotation
    cmap='Blues' # change the color palette
);
